# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("https://raw.githubusercontent.com/rohitgupta29/Hackathron_1/master/hack_2_batch_manufacturing/datasets/train.csv")
train_df.head()
# Out:
#     Id       x0_t0       x0_t1       x0_t2       x0_t3       x0_t4  \
# 0  706  762.212216  753.162754  754.610620  762.787135  768.170347
# 1  239  762.671780  746.631882  745.807832  755.992886  761.814347
# 2  613  766.867777  756.642963  750.059697  756.377980  760.087594
# 3  588  751.077287  758.230866  761.391167  763.190054  768.715192
# 4  780  772.430815  772.254344  772.322597  771.926261  768.820073
#
#         x0_t5       x0_t6     x1_t0     x1_t1  ...     x53_t5  x53_t6  \
# 0  769.815486  750.950000  0.902534  0.873314  ...  87.200000    87.2
# 1  766.110745  762.535189  1.366119  1.358298  ...  72.613391    87.2
# 2  758.380275  750.950000  0.821431  0.825063  ...  87.200000    87.2
# 3  770.447814  750.950000  0.712874  0.744777  ...  87.200000    87.2
# 4  772.908223  750.950000  0.742664  0.676266  ...  87.200000    87.2
#
#      x54_t0    x54_t1    x54_t2    x54_t3    x54_t4   x54_t5  x54_t6    y2
# ...

# %%
train_df["X0"] = train_df[["x0_t0","x0_t1","x0_t2","x0_t3","x0_t4","x0_t5","x0_t6"]].mean(axis=1)
plt.plot(train_df["X0"])

# %%
def average(X,c0,c1,c2,c3,c4,c5,c6):
    train_df[X] = train_df[[c0,c1,c2,c3,c4,c5,c6]].mean(axis=1)
    train_df.drop([c0,c1,c2,c3,c4,c5,c6], axis = 1)
    return train_df[X],plt.plot(train_df[X])

# %%
x1 = average("X1","x1_t0","x1_t1","x1_t2","x1_t3","x1_t4","x1_t5","x1_t6")

# %%
average("X2","x2_t0","x2_t1","x2_t2","x2_t3","x2_t4","x2_t5","x2_t6")
# Out:
# (0      1.0
#  1      1.0
#  2      1.0
#  3      1.0
#  4      1.0
#        ...
#  789    1.0
#  790    1.0
#  791    1.0
#  792    1.0
#  793    1.0
#  Name: X2, Length: 794, dtype: float64,
#  [<matplotlib.lines.Line2D at 0x29811245088>])

# %%
x3 = average("X3","x3_t0","x3_t1","x3_t2","x3_t3","x3_t4","x3_t5","x3_t6")

# %%
x4 = average("X4","x4_t0","x4_t1","x4_t2","x4_t3","x4_t4","x4_t5","x4_t6")

# %%
x5 = average("X5","x5_t0","x5_t1","x5_t2","x5_t3","x5_t4","x5_t5","x5_t6")

# %%
x6 = average("X6","x6_t0","x6_t1","x6_t2","x6_t3","x6_t4","x6_t5","x6_t6")

# %%
x7 = average("X7","x7_t0","x7_t1","x7_t2","x7_t3","x7_t4","x7_t5","x7_t6")

# %%
x8 = average("X8","x8_t0","x8_t1","x8_t2","x8_t3","x8_t4","x8_t5","x8_t6")

# %%
x9 = average("X9","x9_t0","x9_t1","x9_t2","x9_t3","x9_t4","x9_t5","x9_t6")

# %%
x10 = average("X10","x10_t0","x10_t1","x10_t2","x10_t3","x10_t4","x10_t5","x10_t6")

# %%
x11 = average("X11","x11_t0","x11_t1","x11_t2","x11_t3","x11_t4","x11_t5","x11_t6")

# %%
x12 = average("X12","x12_t0","x12_t1","x12_t2","x12_t3","x12_t4","x12_t5","x12_t6")

# %%
x13 = average("X13","x13_t0","x13_t1","x13_t2","x13_t3","x13_t4","x13_t5","x13_t6")

# %%
x14 = average("X14","x14_t0","x14_t1","x14_t2","x14_t3","x14_t4","x14_t5","x14_t6")

# %%
x15 = average("X15","x15_t0","x15_t1","x15_t2","x15_t3","x15_t4","x15_t5","x15_t6")

# %%
x16 = average("X16","x16_t0","x16_t1","x16_t2","x16_t3","x16_t4","x16_t5","x16_t6")

# %%
x17 = average("X17","x17_t0","x17_t1","x17_t2","x17_t3","x17_t4","x17_t5","x17_t6")

# %%
x18 = average("X18","x18_t0","x18_t1","x18_t2","x18_t3","x18_t4","x18_t5","x18_t6")

# %%
x19 = average("X19","x19_t0","x19_t1","x19_t2","x19_t3","x19_t4","x19_t5","x19_t6")

# %%
x20 = average("X20","x20_t0","x20_t1","x20_t2","x20_t3","x20_t4","x20_t5","x20_t6")

# %%
x21 = average("X21","x21_t0","x21_t1","x21_t2","x21_t3","x21_t4","x21_t5","x21_t6")

# %%
x22 = average("X22","x22_t0","x22_t1","x22_t2","x22_t3","x22_t4","x22_t5","x22_t6")

# %%
x23 = average("X23","x23_t0","x23_t1","x23_t2","x23_t3","x23_t4","x23_t5","x23_t6")

# %%
x24 = average("X24","x24_t0","x24_t1","x24_t2","x24_t3","x24_t4","x24_t5","x24_t6")

# %%
x25 = average("X25","x25_t0","x25_t1","x25_t2","x25_t3","x25_t4","x25_t5","x25_t6")

# %%
x26 = average("X26","x26_t0","x26_t1","x26_t2","x26_t3","x26_t4","x26_t5","x26_t6")

# %%
x27 = average("X27","x27_t0","x27_t1","x27_t2","x27_t3","x27_t4","x27_t5","x27_t6")

# %%
x28 = average("X28","x28_t0","x28_t1","x28_t2","x28_t3","x28_t4","x28_t5","x28_t6")

# %%
x29 = average("X29","x29_t0","x29_t1","x29_t2","x29_t3","x29_t4","x29_t5","x29_t6")

# %%
x30 = average("X30","x30_t0","x30_t1","x30_t2","x30_t3","x30_t4","x30_t5","x30_t6")

# %%
x31 = average("X31","x31_t0","x31_t1","x31_t2","x31_t3","x31_t4","x31_t5","x31_t6")

# %%
x32 = average("X32","x32_t0","x32_t1","x32_t2","x32_t3","x32_t4","x32_t5","x32_t6")

# %%
x33 = average("X33","x33_t0","x33_t1","x33_t2","x33_t3","x33_t4","x33_t5","x33_t6")

# %%
x34 = average("X34","x34_t0","x34_t1","x34_t2","x34_t3","x34_t4","x34_t5","x34_t6")

# %%
x35 = average("X35","x35_t0","x35_t1","x35_t2","x35_t3","x35_t4","x35_t5","x35_t6")

# %%
x36 = average("X36","x36_t0","x36_t1","x36_t2","x36_t3","x36_t4","x36_t5","x36_t6")

# %%
x37 = average("X37","x37_t0","x37_t1","x37_t2","x37_t3","x37_t4","x37_t5","x37_t6")

# %%
x38 = average("X38","x38_t0","x38_t1","x38_t2","x38_t3","x38_t4","x38_t5","x38_t6")

# %%
x39 = average("X39","x39_t0","x39_t1","x39_t2","x39_t3","x39_t4","x39_t5","x39_t6")

# %%
x40 = average("X40","x40_t0","x40_t1","x40_t2","x40_t3","x40_t4","x40_t5","x40_t6")

# %%
x41 = average("X41","x41_t0","x41_t1","x41_t2","x41_t3","x41_t4","x41_t5","x41_t6")

# %%
x42 = average("X42","x42_t0","x42_t1","x42_t2","x42_t3","x42_t4","x42_t5","x42_t6")

# %%
x43 = average("X43","x43_t0","x43_t1","x43_t2","x43_t3","x43_t4","x43_t5","x43_t6")

# %%
x44 = average("X44","x44_t0","x44_t1","x44_t2","x44_t3","x44_t4","x44_t5","x44_t6")

# %%
x45 = average("X45","x45_t0","x45_t1","x45_t2","x45_t3","x45_t4","x45_t5","x45_t6")

# %%
x46 = average("X46","x46_t0","x46_t1","x46_t2","x46_t3","x46_t4","x46_t5","x46_t6")

# %%
x47 = average("X47","x47_t0","x47_t1","x47_t2","x47_t3","x47_t4","x47_t5","x47_t6")

# %%
x48 = average("X48","x48_t0","x48_t1","x48_t2","x48_t3","x48_t4","x48_t5","x48_t6")

# %%
x49 = average("X49","x49_t0","x49_t1","x49_t2","x49_t3","x49_t4","x49_t5","x49_t6")

# %%
x50 = average("X50","x50_t0","x50_t1","x50_t2","x50_t3","x50_t4","x50_t5","x50_t6")

# %%
x51 = average("X51","x51_t0","x51_t1","x51_t2","x51_t3","x51_t4","x51_t5","x51_t6")

# %%
x52 = average("X52","x52_t0","x52_t1","x52_t2","x52_t3","x52_t4","x52_t5","x52_t6")

# %%
x53 = average("X53","x53_t0","x53_t1","x53_t2","x53_t3","x53_t4","x53_t5","x53_t6")

# %%
x54 = average("X54","x54_t0","x54_t1","x54_t2","x54_t3","x54_t4","x54_t5","x54_t6")
